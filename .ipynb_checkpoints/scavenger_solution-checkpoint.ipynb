# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://api.github.com/users/ta-datapt-bcn/repos'

# %%
response = requests.get(url, auth=('peterfnc', '800ec24f4aa69a8a16ea53eaf6421b0c25d0065f'))
results = response.json()
results
# Out:
# [{'id': 186247516,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxODYyNDc1MTY=',
#   'name': 'data-prework-labs',
#   'full_name': 'ta-datapt-bcn/data-prework-labs',
#   'private': False,
#   'owner': {'login': 'ta-datapt-bcn',
#    'id': 50545821,
#    'node_id': 'MDQ6VXNlcjUwNTQ1ODIx',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/50545821?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ta-datapt-bcn',
#    'html_url': 'https://github.com/ta-datapt-bcn',
#    'followers_url': 'https://api.github.com/users/ta-datapt-bcn/followers',
#    'following_url': 'https://api.github.com/users/ta-datapt-bcn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ta-datapt-bcn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ta-datapt-bcn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ta-datapt-bcn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ta-datapt-bcn/orgs',
# ...

# %%
from pandas.io.json import json_normalize

results = response.json()

repos = json_normalize(results)

repos.head()
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/ta-datapt-bcn/dat...     False
# 1  https://api.github.com/repos/ta-datapt-bcn/kat...     False
# 2  https://api.github.com/repos/ta-datapt-bcn/lab...     False
# 3  https://api.github.com/repos/ta-datapt-bcn/lab...     False
# 4  https://api.github.com/repos/ta-datapt-bcn/lab...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/ta-datapt-bcn/dat...
# 1  https://api.github.com/repos/ta-datapt-bcn/kat...
# 2  https://api.github.com/repos/ta-datapt-bcn/lab...
# 3  https://api.github.com/repos/ta-datapt-bcn/lab...
# 4  https://api.github.com/repos/ta-datapt-bcn/lab...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/ta-datapt-bcn/dat...
# 1  https://api.github.com/repos/ta-datapt-bcn/kat...
# 2  https://api.github.com/repos/ta-datapt-bcn/lab...
# ...

# %%
repo_names = repos['forks_url'].tolist()
repo_names
# Out:
# ['https://api.github.com/repos/ta-datapt-bcn/data-prework-labs/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/katas_challenge/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-advanced-regex/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-advanced-sql/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-advanced-web-scraping/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-API-scavenger/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-code-efficiency/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-data-cleaning/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-error-handling/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-functional-programming/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-git-basics-merge-conflicts/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-import-export/forks',
#  'https://api.github.com/repos/ta-datapt-bcn/lab-lambda-functions/forks',
# ...

# %%
url2 = 'https://api.github.com/repos/ta-datapt-bcn/lab-advanced-web-scraping/forks'

response = requests.get(url2, auth=('peterfnc', '800ec24f4aa69a8a16ea53eaf6421b0c25d0065f'))
results = response.json()
results
# Out:
# [{'id': 196444458,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTY0NDQ0NTg=',
#   'name': 'lab-advanced-web-scraping',
#   'full_name': 'jordimarsal/lab-advanced-web-scraping',
#   'private': False,
#   'owner': {'login': 'jordimarsal',
#    'id': 7162023,
#    'node_id': 'MDQ6VXNlcjcxNjIwMjM=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/7162023?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jordimarsal',
#    'html_url': 'https://github.com/jordimarsal',
#    'followers_url': 'https://api.github.com/users/jordimarsal/followers',
#    'following_url': 'https://api.github.com/users/jordimarsal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jordimarsal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jordimarsal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jordimarsal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jordimarsal/orgs',
# ...

# %%
results = response.json()

fork = json_normalize(results)

fork.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license', 'merges_url',
#        'milestones_url', 'mirror_url', 'name', 'node_id', 'notifications_url',
#        'open_issues', 'open_issues_count', 'owner.avatar_url',
#        'owner.events_url', 'owner.followers_url', 'owner.following_url',
# ...

# %%
fork['language'][0]
# Out:
# 'Jupyter Notebook'

# %%
len(fork['language'])
# Out:
# 10

# %%
# not sure why it doesn't work when i try to loop it

languages = []

for i in repo_names:
    response = requests.get(i, auth=('peterfnc', '800ec24f4aa69a8a16ea53eaf6421b0c25d0065f'))
    results = response.json()
    fork = json_normalize(results)
    
    languages.append(fork['language'][0])
    
set(languages)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'language'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-f2a69c078f09> in <module>()
# ...
